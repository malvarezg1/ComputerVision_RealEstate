# %% [markdown]
# # Modelo de clasificación por tipo de espacio

# %% [markdown]
# ### Importaciones

# %%
import numpy as np
import os
import PIL
import sklearn

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential
import tensorflow_datasets as tfds
import matplotlib.pyplot as plt

import seaborn as sn
import pandas as pd
from datetime import datetime

# %% [markdown]
# ### Construcción de dataset

# %%
#Preprocesamiento de los datos
directory="E:/TesisMA/Datos/DataCombinada"
#directory1="E:/TesisMA/Datos/DataB"
img_height=256
img_width=256
batch_size = 32
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
  directory,
  validation_split=0.2,
  subset="training",
  seed=123,
  image_size=(img_height, img_width))

val_ds = tf.keras.preprocessing.image_dataset_from_directory(
  directory,
  validation_split=0.2,
  subset="validation",
  seed=123,
  image_size=(img_height, img_width))

#val_mc= tf.keras.preprocessing.image_dataset_from_directory(
 # directory1,
  #seed=123,
  #image_size=(img_height, img_width))
# Out:
# Found 6506 files belonging to 5 classes.
# Using 5205 files for training.
# Found 6506 files belonging to 5 classes.
# Using 1301 files for validation.

# %% [markdown]
# ### Analisis del dataset

# %%
class_names = train_ds.class_names
print(class_names)
num_classes = 5
# Out:
# ['bathroom', 'bedroom', 'dining_room', 'kitchen', 'living_room']

# %%
y = np.concatenate([y for x, y in train_ds], axis=0)
labels = list(y)
elements_per_class = []
fig=plt.figure(figsize=(10,4), dpi= 100, facecolor='w', edgecolor='k')
for i in range(0,num_classes):
    elements_per_class.append(labels.count(i))
print(elements_per_class)
plt.bar(class_names,elements_per_class,color=(0.2, 0.4, 0.6, 0.6))
# Out:
# [1173, 1848, 472, 1157, 555]
# <BarContainer object of 5 artists>

# %%
labels1 = np.concatenate([y for x, y in val_ds], axis=0)
labels1 = list(labels1)
elements_per_class1 = []
fig=plt.figure(figsize=(10,4), dpi= 100, facecolor='w', edgecolor='k')
for i in range(0,num_classes):
    elements_per_class1.append(labels1.count(i))
print(sum(elements_per_class1))
plt.bar(class_names,elements_per_class1,color=(0.2, 0.6, 0.4, 0.6))
# Out:
# 1301
# <BarContainer object of 5 artists>

# %%
labels_mc = np.concatenate([y for x, y in val_mc], axis=0)
labels = list(labels_mc)
lista = []
fig=plt.figure(figsize=(10,4), dpi= 100, facecolor='w', edgecolor='k')
for i in range(0,9):
    lista.append(labels.count(i))
print(sum(lista))
plt.bar(class_names,lista)

# %%
plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
  for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.title(class_names[labels[i]])
    plt.axis("off")

# %%
AUTOTUNE = tf.data.AUTOTUNE

train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

# %% [markdown]
# ### Data augmentation

# %%
data_augmentation = keras.Sequential(
  [
    layers.experimental.preprocessing.RandomFlip("horizontal", input_shape=(img_height, img_width,3)),
    layers.experimental.preprocessing.RandomRotation(0.1),
    layers.experimental.preprocessing.RandomZoom(0.1),
  ]
)

# %% [markdown]
# ### CNN

# %%
model = Sequential([
  #Capa para realizar data augmantation
  data_augmentation,
  #Priemera capa entrada de 256x256 x3 canales de color
  layers.experimental.preprocessing.Rescaling(1/255, input_shape=(256, 256, 3)),
  layers.Conv2D(16, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(32, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(64, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
 # layers.Dropout(0.1), #    Si empiza a haber ploblemas se pone el dropout 
  layers.Flatten(),
  #layers.BatchNormalization(),
  layers.Dense(128, activation='relu', kernel_initializer="he_normal"),
  #layers.BatchNormalization(),
  layers.Dense(64, activation='relu',kernel_initializer="he_normal"),
  #layers.BatchNormalization(),
  layers.Dense(num_classes, activation='softmax')
])

# %%
opt = tf.keras.optimizers.Adam(learning_rate=0.001)
model.compile(optimizer=opt,
              loss=tf.keras.losses.SparseCategoricalCrossentropy(),
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# sequential (Sequential)      (None, 256, 256, 3)       0
# _________________________________________________________________
# rescaling (Rescaling)        (None, 256, 256, 3)       0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 256, 256, 16)      448
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 128, 128, 16)      0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 128, 128, 32)      4640
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 64, 64, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 64, 64, 64)        18496
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 32, 32, 64)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 65536)             0
# _________________________________________________________________
# dense (Dense)                (None, 128)               8388736
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                8256
# _________________________________________________________________
# dense_2 (Dense)              (None, 5)                 325
# =================================================================
# Total params: 8,420,901
# Trainable params: 8,420,901
# Non-trainable params: 0
# _________________________________________________________________

# %%
weights = sklearn.utils.class_weight.compute_class_weight('balanced',np.arange(9),y)
weights
# Out:
# C:\Users\m.alvarezg1\anaconda3\lib\site-packages\sklearn\utils\validation.py:70: FutureWarning: Pass classes=[0 1 2 3 4 5 6 7 8], y=[2 5 3 ... 5 1 2] as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   warnings.warn(f"Pass {args_msg} as keyword args. From version "
# array([ 4.90935673,  0.61671258,  0.31781185,  1.01114122,  4.72292546,
#         0.56276186,  1.32779755,  5.04204204, 10.08408408])

# %%
weights={}
for i in range(0,9):
    weights[i]=(1/elements_per_class[i])*(sum(elements_per_class)/9)
weights
# Out:
# {0: 4.909356725146198,
#  1: 0.6167125803489439,
#  2: 0.3178118493280333,
#  3: 1.0111412225233363,
#  4: 4.722925457102672,
#  5: 0.562761856879504,
#  6: 1.3277975484381177,
#  7: 5.042042042042042,
#  8: 10.084084084084084}

# %%
epochs=80
history = model.fit(
train_ds,
validation_data=val_ds,
epochs=epochs,
#class_weight=weights,
#callbacks=[tensorboard_cb]
)
# Out:
# Epoch 1/80
# 163/163 [==============================] - 650s 4s/step - loss: 1.4928 - accuracy: 0.3535 - val_loss: 1.2797 - val_accuracy: 0.4450
# Epoch 2/80
# 163/163 [==============================] - 555s 3s/step - loss: 1.3147 - accuracy: 0.4248 - val_loss: 1.3180 - val_accuracy: 0.4235
# Epoch 3/80
# 163/163 [==============================] - 547s 3s/step - loss: 1.2582 - accuracy: 0.4586 - val_loss: 1.2239 - val_accuracy: 0.4842
# Epoch 4/80
# 163/163 [==============================] - 545s 3s/step - loss: 1.2016 - accuracy: 0.5009 - val_loss: 1.2504 - val_accuracy: 0.4766
# Epoch 5/80
# 163/163 [==============================] - 553s 3s/step - loss: 1.1754 - accuracy: 0.5101 - val_loss: 1.1874 - val_accuracy: 0.4942
# Epoch 6/80
# 163/163 [==============================] - 546s 3s/step - loss: 1.1566 - accuracy: 0.5306 - val_loss: 1.1316 - val_accuracy: 0.5596
# Epoch 7/80
# 163/163 [==============================] - 548s 3s/step - loss: 1.1171 - accuracy: 0.5487 - val_loss: 1.1112 - val_accuracy: 0.5511
# Epoch 8/80
# 163/163 [==============================] - 538s 3s/step - loss: 1.0889 - accuracy: 0.5589 - val_loss: 1.0817 - val_accuracy: 0.5650
# Epoch 9/80
# 163/163 [==============================] - 541s 3s/step - loss: 1.0561 - accuracy: 0.5775 - val_loss: 1.0947 - val_accuracy: 0.5734
# Epoch 10/80
# 163/163 [==============================] - 540s 3s/step - loss: 1.0524 - accuracy: 0.5814 - val_loss: 1.0475 - val_accuracy: 0.5842
# Epoch 11/80
# 163/163 [==============================] - 533s 3s/step - loss: 1.0093 - accuracy: 0.5992 - val_loss: 1.0770 - val_accuracy: 0.5872
# Epoch 12/80
# 163/163 [==============================] - 533s 3s/step - loss: 0.9849 - accuracy: 0.6127 - val_loss: 1.0340 - val_accuracy: 0.5895
# Epoch 13/80
# 163/163 [==============================] - 579s 4s/step - loss: 0.9707 - accuracy: 0.6081 - val_loss: 1.0535 - val_accuracy: 0.5965
# Epoch 14/80
# 163/163 [==============================] - 566s 3s/step - loss: 0.9428 - accuracy: 0.6307 - val_loss: 1.1084 - val_accuracy: 0.5811
# Epoch 15/80
# 163/163 [==============================] - 569s 3s/step - loss: 0.9248 - accuracy: 0.6373 - val_loss: 1.0511 - val_accuracy: 0.5926
# Epoch 16/80
# 163/163 [==============================] - 579s 4s/step - loss: 0.9001 - accuracy: 0.6509 - val_loss: 1.0136 - val_accuracy: 0.6149
# Epoch 17/80
#  26/163 [===>..........................] - ETA: 8:17 - loss: 0.8826 - accuracy: 0.6743

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# #### Confusion matrix

# %%
predictions = np.array([])
labels =  np.array([])
for x, y in val_ds:
  predictions = np.concatenate([predictions, np.argmax(model.predict(x), axis=-1)])  
                               
matriz = tf.math.confusion_matrix(labels=labels1, predictions=predictions).numpy()
sum(sum(matriz))
df_cm = pd.DataFrame(matriz, index = class_names, columns = class_names)
plt.figure(figsize = (10,7))
sn.heatmap(df_cm, annot=True, cmap="YlGnBu",  fmt='g')
# Out:
# <AxesSubplot:>

# %%
metricasCM(matriz)
# Out:
# De todas las X clasificadas solo el %  fue correcto [0.03, 0.13, 0.35, 0.08, 0.02, 0.18, 0.07, 0.0, 0.0]
# De todas las que deberían ser clasificadas como X el % fue corrcto  [0.03, 0.14, 0.46, 0.08, 0.03, 0.12, 0.03, 0.0, 0.0]

# %% [markdown]
# ### Evalucación del modelo usando datos de MC

# %%
report = model.evaluate(val_mc,return_dict=True)
index=["Values"]
table=pd.DataFrame(report,index=index) 
table
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-35-acc0be19db97> in <module>
# ----> 1 report = model.evaluate(val_mc,return_dict=True)
#       2 index=["Values"]
#       3 table=pd.DataFrame(report,index=index)
#       4 table
#
# NameError: name 'val_mc' is not defined

# %% [markdown]
# #### Confusion matrix

# %%
predictions = model.predict(val_mc)

# %%
predictions=np.argmax(predictions,axis=1)
matriz = tf.math.confusion_matrix(labels=labels_mc, predictions=predictions).numpy()
sum(sum(matriz))
df_cm = pd.DataFrame(matriz, index = class_names, columns = class_names)
plt.figure(figsize = (10,7))
sn.heatmap(df_cm, annot=True, cmap="YlGnBu",  fmt='g')
# Out:
# <AxesSubplot:>

# %%
def metricasCM(matriz):
    # Bien clasificados sobre columna / De todas las X clasificadas solo el %  fue correcto
    metrica1= []
    # Bien clasificados sobre la fila / De todas las que deberías ser clasificadas como X solo el % fue corrcto 
    metrica2= []
    for j in range(0,9):
        suma=0
        for i in range(0,9):
            suma=suma+matriz[i][j]
        metrica1.append((matriz[j][j]/suma).round(2))
        metrica2.append((matriz[j][j]/sum(matriz[j])).round(2))
    print("De todas las X clasificadas solo el %  fue correcto",metrica1)
    print("De todas las que deberían ser clasificadas como X el % fue corrcto ",metrica2)
metricasCM(matriz)
# Out:
# De todas las X clasificadas solo el %  fue correcto [0.03, 0.13, 0.35, 0.08, 0.02, 0.18, 0.07, 0.0, 0.0]
# De todas las que deberían ser clasificadas como X el % fue corrcto  [0.03, 0.14, 0.46, 0.08, 0.03, 0.12, 0.03, 0.0, 0.0]

# %% [markdown]
# #### TensorBoard

# %%
root_dir = "E:/TesisMA/Modelos/my_log"
def get_run_dir():
    import time
    run_id=time.strftime("run_%Y_%m_%d-%H_%M_%D")
    return os.path.join(root_dir,run_id)

tensorboard_cb = keras.callbacks.TensorBoard(get_run_dir())

# %%
# %load_ext tensorboard
# %tensorboard --logdir=E:/TesisMA/Modelos/my_log --port 6006
# Out:
#       <iframe id="tensorboard-frame-985de6c1fa18de67" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-985de6c1fa18de67");
#           const url = new URL("/", window.location);
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %% [markdown]
# #### Guardar modelo

# %%
model.save("E:/TesisMA/Modelos/ModeloHe_normal")
# Out:
# INFO:tensorflow:Assets written to: E:/TesisMA/Modelos/ModeloHe_normal\assets

# %%
ruta = "C:/Users/m.alvarezg1/Documents/DataB/Apartamento1024_3.jpg"
img = keras.preprocessing.image.load_img(ruta
    , target_size=(256, 256)
)
img_array = keras.preprocessing.image.img_to_array(img)
img_array = tf.expand_dims(img_array, 0) # Create a batch
    
predictions = model.predict_classes(img_array)
predictions1 = model.predict(img_array).round(2)
print(predictions)
print(predictions1)

print(
    "This image most likely belongs to {} with a {:.2f} percent confidence."
    .format(class_names[np.argmax(predictions1)], 100 * np.max(predictions1))
)
PIL.Image.open(ruta)
# Out:
# [5]
# [[0.   0.14 0.08 0.11 0.01 0.6  0.03 0.02 0.  ]]
# This image most likely belongs to kitchen with a 60.00 percent confidence.
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1600x1200 at 0x1FBA0EEAAF0>
