# %% [markdown]
# # Modelo de clasificación por tipo de espacio

# %% [markdown]
# ### Importaciones

# %%
import numpy as np
import os
import PIL
import sklearn

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential
import tensorflow_datasets as tfds
from tensorflow.keras.callbacks import Callback
import matplotlib.pyplot as plt

import seaborn as sn
import pandas as pd
from datetime import datetime
# Out:
# C:\Users\m.alvarezg1\anaconda3\lib\site-packages\numpy\_distributor_init.py:30: UserWarning: loaded more than 1 DLL from .libs:
# C:\Users\m.alvarezg1\anaconda3\lib\site-packages\numpy\.libs\libopenblas.PYQHXLVVQ7VESDPUVUADXEVJOBGHJPAY.gfortran-win_amd64.dll
# C:\Users\m.alvarezg1\anaconda3\lib\site-packages\numpy\.libs\libopenblas.WCDJNK7YVMPZQ2ME2ZZHJJRJ3JIKNDB7.gfortran-win_amd64.dll
#   warnings.warn("loaded more than 1 DLL from .libs:"

# %% [markdown]
# ### Construcción de dataset

# %%
#Preprocesamiento de los datos
directory="E:/TesisMA/Datos/DataCLAHE"
#directory1="E:/TesisMA/Datos/DataB"
img_height=256
img_width=256
batch_size = 32
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
  directory,
  validation_split=0.2,
  subset="training",
  seed=123,
  image_size=(img_height, img_width))

val_ds = tf.keras.preprocessing.image_dataset_from_directory(
  directory,
  validation_split=0.2,
  subset="validation",
  seed=123,
  image_size=(img_height, img_width))
# Out:
# Found 6773 files belonging to 5 classes.
# Using 5419 files for training.
# Found 6773 files belonging to 5 classes.
# Using 1354 files for validation.

# %% [markdown]
# ### Analisis del dataset

# %%
class_names = train_ds.class_names
print(class_names)
num_classes = 5
total=[]
# Out:
# ['bathroom', 'bedroom', 'dining_room', 'kitchen', 'living_room']

# %%
y = np.concatenate([y for x, y in train_ds], axis=0)
labels = list(y)
elements_per_class = []
for i in range(0,num_classes):
    elements_per_class.append(labels.count(i))
    total.append(labels.count(i))
print(elements_per_class)
plt.bar(class_names,elements_per_class,color=(0.2, 0.4, 0.6, 0.6));
# Out:
# [1230, 1845, 501, 1222, 621]

# %%
labels1 = np.concatenate([y for x, y in val_ds], axis=0)
labels1 = list(labels1)
elements_per_class1 = []

for i in range(0,num_classes):
    elements_per_class1.append(labels1.count(i))
    total[i]=total[i]+labels1.count(i)
print(sum(elements_per_class1))
plt.bar(class_names,elements_per_class1,color=(0.2, 0.6, 0.4, 0.6));
# Out:
# 1354

# %%
plt.bar(class_names,total,color=(0.2, 0.4, 0.6, 0.6));

# %%
plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
  for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.title(class_names[labels[i]])
    plt.axis("off")

# %%
AUTOTUNE = tf.data.AUTOTUNE

train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

# %% [markdown]
# ### Data augmentation

# %%
data_augmentation = keras.Sequential(
  [
    layers.experimental.preprocessing.RandomFlip("horizontal", input_shape=(img_height, img_width,3)),
    layers.experimental.preprocessing.RandomRotation(0.2),
    layers.experimental.preprocessing.RandomZoom(0.2),
  ]
)

# %% [markdown]
# ### CNN

# %%
model = Sequential([
  #Capa para realizar data augmantation
  data_augmentation,
  #Priemera capa entrada de 256x256 x3 canales de color
  layers.experimental.preprocessing.Rescaling(1/255, input_shape=(img_height, img_width, 3)),
  layers.Conv2D(16, 3, padding='same', activation='relu'),
  #layers.BatchNormalization(),
  layers.MaxPooling2D(),
  layers.Conv2D(32, 3, padding='same', activation='relu'),
  #layers.BatchNormalization(),
  layers.MaxPooling2D(),
  layers.Conv2D(64, 3, padding='same', activation='relu'),
  #layers.BatchNormalization(),
  layers.MaxPooling2D(),
  layers.Conv2D(128, 3, padding='same', activation='relu'),
  layers.Conv2D(128, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Dropout(0.2), #    Si empiza a haber ploblemas se pone el dropout 
  layers.Flatten(),
  #layers.BatchNormalization(),
  layers.Dense(1024,activation="relu", kernel_initializer="he_normal"),
  #layers.Dropout(0.1),
  #layers.LeakyReLU(alpha=0.1),
  #layers.BatchNormalization(),
  layers.Dense(512,activation="relu", kernel_initializer="he_normal"),
  layers.Dropout(0.1),
  #layers.LeakyReLU(alpha=0.1),
  #layers.BatchNormalization(),
  layers.Dense(num_classes, activation='softmax')
])

# %% [markdown]
# ### LRF Finder

# %%
opt = tf.keras.optimizers.Adam(learning_rate=0.0005)
model.compile(optimizer=opt,
              loss=tf.keras.losses.SparseCategoricalCrossentropy(),
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_23"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# sequential_22 (Sequential)   (None, 256, 256, 3)       0
# _________________________________________________________________
# rescaling_12 (Rescaling)     (None, 256, 256, 3)       0
# _________________________________________________________________
# conv2d_53 (Conv2D)           (None, 256, 256, 16)      448
# _________________________________________________________________
# max_pooling2d_47 (MaxPooling (None, 128, 128, 16)      0
# _________________________________________________________________
# conv2d_54 (Conv2D)           (None, 128, 128, 32)      4640
# _________________________________________________________________
# max_pooling2d_48 (MaxPooling (None, 64, 64, 32)        0
# _________________________________________________________________
# conv2d_55 (Conv2D)           (None, 64, 64, 64)        18496
# _________________________________________________________________
# max_pooling2d_49 (MaxPooling (None, 32, 32, 64)        0
# _________________________________________________________________
# conv2d_56 (Conv2D)           (None, 32, 32, 128)       73856
# _________________________________________________________________
# conv2d_57 (Conv2D)           (None, 32, 32, 128)       147584
# _________________________________________________________________
# max_pooling2d_50 (MaxPooling (None, 16, 16, 128)       0
# _________________________________________________________________
# dropout_19 (Dropout)         (None, 16, 16, 128)       0
# _________________________________________________________________
# flatten_12 (Flatten)         (None, 32768)             0
# _________________________________________________________________
# dense_36 (Dense)             (None, 1024)              33555456
# _________________________________________________________________
# dense_37 (Dense)             (None, 512)               524800
# _________________________________________________________________
# dropout_20 (Dropout)         (None, 512)               0
# _________________________________________________________________
# dense_38 (Dense)             (None, 5)                 2565
# =================================================================
# Total params: 34,327,845
# Trainable params: 34,327,845
# Non-trainable params: 0
# _________________________________________________________________

# %%
checkpoint_filepath="E:/TesisMA/Modelos/256_CLAHE/Best_Modelo5_256_5_conv_dropout02-01_n1024_512_lr0005_dsCLAHE"
model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_filepath,
    save_weights_only=False,
    monitor='val_accuracy',
    mode='max',
    save_best_only=True)

# %%
epochs=100
history = model.fit(
train_ds,
validation_data=val_ds,
epochs=epochs,
callbacks=[model_checkpoint_callback]
)
# Out:
# Epoch 1/100
# 170/170 [==============================] - 328s 2s/step - loss: 1.4550 - accuracy: 0.3451 - val_loss: 1.4111 - val_accuracy: 0.3486
# INFO:tensorflow:Assets written to: E:/TesisMA/Modelos/256_CLAHE\Best_Modelo5_256_5_conv_dropout02-01_n1024_512_lr0005_dsCLAHE\assets
# Epoch 2/100
# 170/170 [==============================] - 301s 2s/step - loss: 1.3446 - accuracy: 0.3879 - val_loss: 1.4787 - val_accuracy: 0.3331
# Epoch 3/100
# 170/170 [==============================] - 305s 2s/step - loss: 1.3181 - accuracy: 0.4067 - val_loss: 1.3813 - val_accuracy: 0.3870
# INFO:tensorflow:Assets written to: E:/TesisMA/Modelos/256_CLAHE\Best_Modelo5_256_5_conv_dropout02-01_n1024_512_lr0005_dsCLAHE\assets
# Epoch 4/100
# 170/170 [==============================] - 304s 2s/step - loss: 1.2785 - accuracy: 0.4255 - val_loss: 1.3433 - val_accuracy: 0.4084
# INFO:tensorflow:Assets written to: E:/TesisMA/Modelos/256_CLAHE\Best_Modelo5_256_5_conv_dropout02-01_n1024_512_lr0005_dsCLAHE\assets
# Epoch 5/100
# 170/170 [==============================] - 309s 2s/step - loss: 1.2631 - accuracy: 0.4375 - val_loss: 1.2561 - val_accuracy: 0.4402
# INFO:tensorflow:Assets written to: E:/TesisMA/Modelos/256_CLAHE\Best_Modelo5_256_5_conv_dropout02-01_n1024_512_lr0005_dsCLAHE\assets
# Epoch 6/100
# 170/170 [==============================] - 311s 2s/step - loss: 1.2300 - accuracy: 0.4623 - val_loss: 1.2734 - val_accuracy: 0.4453
# INFO:tensorflow:Assets written to: E:/TesisMA/Modelos/256_CLAHE\Best_Modelo5_256_5_conv_dropout02-01_n1024_512_lr0005_dsCLAHE\assets
# Epoch 7/100
# 170/170 [==============================] - 304s 2s/step - loss: 1.2180 - accuracy: 0.4800 - val_loss: 1.3540 - val_accuracy: 0.4535
# INFO:tensorflow:Assets written to: E:/TesisMA/Modelos/256_CLAHE\Best_Modelo5_256_5_conv_dropout02-01_n1024_512_lr0005_dsCLAHE\assets
# Epoch 8/100
# 170/170 [==============================] - 307s 2s/step - loss: 1.1801 - accuracy: 0.4977 - val_loss: 1.2082 - val_accuracy: 0.5096
# INFO:tensorflow:Assets written to: E:/TesisMA/Modelos/256_CLAHE\Best_Modelo5_256_5_conv_dropout02-01_n1024_512_lr0005_dsCLAHE\assets
# Epoch 9/100
# 170/170 [==============================] - 321s 2s/step - loss: 1.1425 - accuracy: 0.5274 - val_loss: 1.2704 - val_accuracy: 0.4889
# Epoch 10/100
# 170/170 [==============================] - 307s 2s/step - loss: 1.1121 - accuracy: 0.5429 - val_loss: 1.0911 - val_accuracy: 0.5635
# INFO:tensorflow:Assets written to: E:/TesisMA/Modelos/256_CLAHE\Best_Modelo5_256_5_conv_dropout02-01_n1024_512_lr0005_dsCLAHE\assets
# Epoch 11/100
# 170/170 [==============================] - 309s 2s/step - loss: 1.1004 - accuracy: 0.5580 - val_loss: 1.1013 - val_accuracy: 0.5805
# INFO:tensorflow:Assets written to: E:/TesisMA/Modelos/256_CLAHE\Best_Modelo5_256_5_conv_dropout02-01_n1024_512_lr0005_dsCLAHE\assets
# Epoch 12/100
# 170/170 [==============================] - 312s 2s/step - loss: 1.0515 - accuracy: 0.5746 - val_loss: 1.0107 - val_accuracy: 0.6189
# INFO:tensorflow:Assets written to: E:/TesisMA/Modelos/256_CLAHE\Best_Modelo5_256_5_conv_dropout02-01_n1024_512_lr0005_dsCLAHE\assets
# Epoch 13/100
# 170/170 [==============================] - 314s 2s/step - loss: 1.0338 - accuracy: 0.5879 - val_loss: 1.1340 - val_accuracy: 0.5576
# Epoch 14/100
# 170/170 [==============================] - 312s 2s/step - loss: 0.9948 - accuracy: 0.5996 - val_loss: 0.9407 - val_accuracy: 0.6359
# INFO:tensorflow:Assets written to: E:/TesisMA/Modelos/256_CLAHE\Best_Modelo5_256_5_conv_dropout02-01_n1024_512_lr0005_dsCLAHE\assets
# Epoch 15/100
# 170/170 [==============================] - 297s 2s/step - loss: 0.9869 - accuracy: 0.6066 - val_loss: 1.0015 - val_accuracy: 0.6145
# Epoch 16/100
# 170/170 [==============================] - 302s 2s/step - loss: 0.9575 - accuracy: 0.6204 - val_loss: 0.9460 - val_accuracy: 0.6448
# INFO:tensorflow:Assets written to: E:/TesisMA/Modelos/256_CLAHE\Best_Modelo5_256_5_conv_dropout02-01_n1024_512_lr0005_dsCLAHE\assets
# Epoch 17/100
# 170/170 [==============================] - 295s 2s/step - loss: 0.9488 - accuracy: 0.6272 - val_loss: 0.9531 - val_accuracy: 0.6381
# Epoch 18/100
# 170/170 [==============================] - 296s 2s/step - loss: 0.9212 - accuracy: 0.6420 - val_loss: 0.9203 - val_accuracy: 0.6521
# INFO:tensorflow:Assets written to: E:/TesisMA/Modelos/256_CLAHE\Best_Modelo5_256_5_conv_dropout02-01_n1024_512_lr0005_dsCLAHE\assets
# Epoch 19/100
# 170/170 [==============================] - 302s 2s/step - loss: 0.9067 - accuracy: 0.6492 - val_loss: 1.0998 - val_accuracy: 0.5968
# Epoch 20/100
# 170/170 [==============================] - 297s 2s/step - loss: 0.8667 - accuracy: 0.6684 - val_loss: 1.0665 - val_accuracy: 0.6071
# Epoch 21/100
# 170/170 [==============================] - 298s 2s/step - loss: 0.8670 - accuracy: 0.6667 - val_loss: 0.9046 - val_accuracy: 0.6448
# Epoch 22/100
# 170/170 [==============================] - 297s 2s/step - loss: 0.8644 - accuracy: 0.6691 - val_loss: 1.0646 - val_accuracy: 0.6049
# Epoch 23/100
# 170/170 [==============================] - 302s 2s/step - loss: 0.8449 - accuracy: 0.6802 - val_loss: 0.9032 - val_accuracy: 0.6610
# INFO:tensorflow:Assets written to: E:/TesisMA/Modelos/256_CLAHE\Best_Modelo5_256_5_conv_dropout02-01_n1024_512_lr0005_dsCLAHE\assets
# Epoch 24/100
# 170/170 [==============================] - 296s 2s/step - loss: 0.8168 - accuracy: 0.6911 - val_loss: 0.8554 - val_accuracy: 0.6706
# INFO:tensorflow:Assets written to: E:/TesisMA/Modelos/256_CLAHE\Best_Modelo5_256_5_conv_dropout02-01_n1024_512_lr0005_dsCLAHE\assets
# Epoch 25/100
# 170/170 [==============================] - 306s 2s/step - loss: 0.7930 - accuracy: 0.7053 - val_loss: 0.8744 - val_accuracy: 0.6677
# Epoch 26/100
# 170/170 [==============================] - 310s 2s/step - loss: 0.7753 - accuracy: 0.7068 - val_loss: 1.0154 - val_accuracy: 0.6381
# Epoch 27/100
# 170/170 [==============================] - 306s 2s/step - loss: 0.7682 - accuracy: 0.7097 - val_loss: 0.9452 - val_accuracy: 0.6595
# Epoch 28/100
# 170/170 [==============================] - 306s 2s/step - loss: 0.7573 - accuracy: 0.7208 - val_loss: 0.8221 - val_accuracy: 0.6913
# INFO:tensorflow:Assets written to: E:/TesisMA/Modelos/256_CLAHE\Best_Modelo5_256_5_conv_dropout02-01_n1024_512_lr0005_dsCLAHE\assets
# Epoch 29/100
# 170/170 [==============================] - 310s 2s/step - loss: 0.7431 - accuracy: 0.7182 - val_loss: 0.9349 - val_accuracy: 0.6632
# Epoch 30/100
# 170/170 [==============================] - 307s 2s/step - loss: 0.7263 - accuracy: 0.7297 - val_loss: 0.8374 - val_accuracy: 0.6883
# Epoch 31/100
# 170/170 [==============================] - 306s 2s/step - loss: 0.7142 - accuracy: 0.7249 - val_loss: 0.8034 - val_accuracy: 0.7001
# INFO:tensorflow:Assets written to: E:/TesisMA/Modelos/256_CLAHE\Best_Modelo5_256_5_conv_dropout02-01_n1024_512_lr0005_dsCLAHE\assets
# Epoch 32/100
# 170/170 [==============================] - 295s 2s/step - loss: 0.6866 - accuracy: 0.7394 - val_loss: 0.9194 - val_accuracy: 0.6780
# Epoch 33/100
# 170/170 [==============================] - 301s 2s/step - loss: 0.6828 - accuracy: 0.7446 - val_loss: 0.8439 - val_accuracy: 0.6846
# Epoch 34/100
# 170/170 [==============================] - 296s 2s/step - loss: 0.6782 - accuracy: 0.7453 - val_loss: 0.9696 - val_accuracy: 0.6581
# Epoch 35/100
# 170/170 [==============================] - 298s 2s/step - loss: 0.6615 - accuracy: 0.7524 - val_loss: 0.8550 - val_accuracy: 0.6898
# Epoch 36/100
# 170/170 [==============================] - 301s 2s/step - loss: 0.6404 - accuracy: 0.7595 - val_loss: 0.8712 - val_accuracy: 0.6928
# Epoch 37/100
# 170/170 [==============================] - 295s 2s/step - loss: 0.6341 - accuracy: 0.7610 - val_loss: 0.8618 - val_accuracy: 0.7046
# INFO:tensorflow:Assets written to: E:/TesisMA/Modelos/256_CLAHE\Best_Modelo5_256_5_conv_dropout02-01_n1024_512_lr0005_dsCLAHE\assets
# Epoch 38/100
# 170/170 [==============================] - 276s 2s/step - loss: 0.6057 - accuracy: 0.7773 - val_loss: 0.8401 - val_accuracy: 0.7120
# INFO:tensorflow:Assets written to: E:/TesisMA/Modelos/256_CLAHE\Best_Modelo5_256_5_conv_dropout02-01_n1024_512_lr0005_dsCLAHE\assets
# Epoch 39/100
# 170/170 [==============================] - 284s 2s/step - loss: 0.6089 - accuracy: 0.7703 - val_loss: 0.8420 - val_accuracy: 0.7038
# Epoch 40/100
# 170/170 [==============================] - 292s 2s/step - loss: 0.5911 - accuracy: 0.7824 - val_loss: 0.9178 - val_accuracy: 0.6913
# Epoch 41/100
# 170/170 [==============================] - 283s 2s/step - loss: 0.5720 - accuracy: 0.7902 - val_loss: 0.8322 - val_accuracy: 0.7142
# INFO:tensorflow:Assets written to: E:/TesisMA/Modelos/256_CLAHE\Best_Modelo5_256_5_conv_dropout02-01_n1024_512_lr0005_dsCLAHE\assets
# Epoch 42/100
# 170/170 [==============================] - 285s 2s/step - loss: 0.5825 - accuracy: 0.7811 - val_loss: 0.9032 - val_accuracy: 0.7068
# Epoch 43/100
# 170/170 [==============================] - 290s 2s/step - loss: 0.5734 - accuracy: 0.7870 - val_loss: 0.8790 - val_accuracy: 0.7016
# Epoch 44/100
# 170/170 [==============================] - 284s 2s/step - loss: 0.5464 - accuracy: 0.8001 - val_loss: 0.9947 - val_accuracy: 0.6669
# Epoch 45/100
# 170/170 [==============================] - 283s 2s/step - loss: 0.5368 - accuracy: 0.8053 - val_loss: 0.8518 - val_accuracy: 0.7149
# INFO:tensorflow:Assets written to: E:/TesisMA/Modelos/256_CLAHE\Best_Modelo5_256_5_conv_dropout02-01_n1024_512_lr0005_dsCLAHE\assets
# Epoch 46/100
# 170/170 [==============================] - 282s 2s/step - loss: 0.5179 - accuracy: 0.8140 - val_loss: 0.9339 - val_accuracy: 0.6898
# Epoch 47/100
# 170/170 [==============================] - 288s 2s/step - loss: 0.5206 - accuracy: 0.8097 - val_loss: 0.9718 - val_accuracy: 0.6869
# Epoch 48/100
# 170/170 [==============================] - 283s 2s/step - loss: 0.5041 - accuracy: 0.8144 - val_loss: 1.0017 - val_accuracy: 0.6699
# Epoch 49/100
# 170/170 [==============================] - 286s 2s/step - loss: 0.4973 - accuracy: 0.8217 - val_loss: 0.8951 - val_accuracy: 0.7090
# Epoch 50/100
# 170/170 [==============================] - 284s 2s/step - loss: 0.4792 - accuracy: 0.8289 - val_loss: 0.9801 - val_accuracy: 0.6802
# Epoch 51/100
# 170/170 [==============================] - 287s 2s/step - loss: 0.4846 - accuracy: 0.8238 - val_loss: 0.8582 - val_accuracy: 0.7046
# Epoch 52/100
# 170/170 [==============================] - 284s 2s/step - loss: 0.4663 - accuracy: 0.8321 - val_loss: 0.9008 - val_accuracy: 0.7075
# Epoch 53/100
# 170/170 [==============================] - 284s 2s/step - loss: 0.4458 - accuracy: 0.8361 - val_loss: 0.9310 - val_accuracy: 0.7009
# Epoch 54/100
# 170/170 [==============================] - 282s 2s/step - loss: 0.4461 - accuracy: 0.8376 - val_loss: 0.9516 - val_accuracy: 0.7001
# Epoch 55/100
# 170/170 [==============================] - 288s 2s/step - loss: 0.4373 - accuracy: 0.8367 - val_loss: 0.9258 - val_accuracy: 0.7097
# Epoch 56/100
# 170/170 [==============================] - 282s 2s/step - loss: 0.4389 - accuracy: 0.8391 - val_loss: 0.9606 - val_accuracy: 0.6920
# Epoch 57/100
# 170/170 [==============================] - 284s 2s/step - loss: 0.4370 - accuracy: 0.8435 - val_loss: 1.0578 - val_accuracy: 0.6861
# Epoch 58/100
# 170/170 [==============================] - 283s 2s/step - loss: 0.4278 - accuracy: 0.8450 - val_loss: 0.9884 - val_accuracy: 0.6905
# Epoch 59/100
# 170/170 [==============================] - 288s 2s/step - loss: 0.4252 - accuracy: 0.8417 - val_loss: 1.0220 - val_accuracy: 0.6905
# Epoch 60/100
# 170/170 [==============================] - 284s 2s/step - loss: 0.4025 - accuracy: 0.8505 - val_loss: 0.9181 - val_accuracy: 0.6898
# Epoch 61/100
# 170/170 [==============================] - 283s 2s/step - loss: 0.3823 - accuracy: 0.8644 - val_loss: 0.9120 - val_accuracy: 0.7260
# INFO:tensorflow:Assets written to: E:/TesisMA/Modelos/256_CLAHE\Best_Modelo5_256_5_conv_dropout02-01_n1024_512_lr0005_dsCLAHE\assets
# Epoch 62/100
# 170/170 [==============================] - 289s 2s/step - loss: 0.3740 - accuracy: 0.8664 - val_loss: 0.9694 - val_accuracy: 0.7149
# Epoch 63/100
# 170/170 [==============================] - 284s 2s/step - loss: 0.3725 - accuracy: 0.8649 - val_loss: 1.0598 - val_accuracy: 0.7208
# Epoch 64/100
# 170/170 [==============================] - 285s 2s/step - loss: 0.3751 - accuracy: 0.8657 - val_loss: 0.9319 - val_accuracy: 0.7061
# Epoch 65/100
# 170/170 [==============================] - 284s 2s/step - loss: 0.3579 - accuracy: 0.8712 - val_loss: 0.9937 - val_accuracy: 0.7031
# Epoch 66/100
# 170/170 [==============================] - 287s 2s/step - loss: 0.3387 - accuracy: 0.8716 - val_loss: 1.0306 - val_accuracy: 0.6883
# Epoch 67/100
# 170/170 [==============================] - 282s 2s/step - loss: 0.3493 - accuracy: 0.8736 - val_loss: 0.9863 - val_accuracy: 0.7134
# Epoch 68/100
# 170/170 [==============================] - 282s 2s/step - loss: 0.3298 - accuracy: 0.8799 - val_loss: 1.0027 - val_accuracy: 0.7216
# Epoch 69/100
# 170/170 [==============================] - 281s 2s/step - loss: 0.3364 - accuracy: 0.8784 - val_loss: 1.0879 - val_accuracy: 0.7105
# Epoch 70/100
# 170/170 [==============================] - 284s 2s/step - loss: 0.3400 - accuracy: 0.8801 - val_loss: 1.0366 - val_accuracy: 0.7046
# Epoch 71/100
# 170/170 [==============================] - 283s 2s/step - loss: 0.3138 - accuracy: 0.8885 - val_loss: 1.1061 - val_accuracy: 0.6979
# Epoch 72/100
# 170/170 [==============================] - 283s 2s/step - loss: 0.3187 - accuracy: 0.8856 - val_loss: 1.1236 - val_accuracy: 0.7097
# Epoch 73/100
# 170/170 [==============================] - 285s 2s/step - loss: 0.3202 - accuracy: 0.8845 - val_loss: 1.0871 - val_accuracy: 0.7046
# Epoch 74/100
# 170/170 [==============================] - 244s 1s/step - loss: 0.3345 - accuracy: 0.8832 - val_loss: 1.0111 - val_accuracy: 0.7009
# Epoch 75/100
# 170/170 [==============================] - 221s 1s/step - loss: 0.3181 - accuracy: 0.8893 - val_loss: 1.0023 - val_accuracy: 0.7208
# Epoch 76/100
# 170/170 [==============================] - 223s 1s/step - loss: 0.2804 - accuracy: 0.9029 - val_loss: 1.0791 - val_accuracy: 0.6994
# Epoch 77/100
# 170/170 [==============================] - 224s 1s/step - loss: 0.3133 - accuracy: 0.8895 - val_loss: 1.1109 - val_accuracy: 0.6942
# Epoch 78/100
# 170/170 [==============================] - 224s 1s/step - loss: 0.3011 - accuracy: 0.8944 - val_loss: 1.1221 - val_accuracy: 0.6883
# Epoch 79/100
# 170/170 [==============================] - 224s 1s/step - loss: 0.2953 - accuracy: 0.8989 - val_loss: 1.1056 - val_accuracy: 0.7046
# Epoch 80/100
# 170/170 [==============================] - 230s 1s/step - loss: 0.2798 - accuracy: 0.9039 - val_loss: 1.0602 - val_accuracy: 0.7282
# INFO:tensorflow:Assets written to: E:/TesisMA/Modelos/256_CLAHE\Best_Modelo5_256_5_conv_dropout02-01_n1024_512_lr0005_dsCLAHE\assets
# Epoch 81/100
# 170/170 [==============================] - 224s 1s/step - loss: 0.2570 - accuracy: 0.9103 - val_loss: 1.0588 - val_accuracy: 0.7201
# Epoch 82/100
# 170/170 [==============================] - 226s 1s/step - loss: 0.2895 - accuracy: 0.9022 - val_loss: 1.0729 - val_accuracy: 0.7267
# Epoch 83/100
# 170/170 [==============================] - 224s 1s/step - loss: 0.2641 - accuracy: 0.9033 - val_loss: 1.0246 - val_accuracy: 0.7201
# Epoch 84/100
# 170/170 [==============================] - 225s 1s/step - loss: 0.2656 - accuracy: 0.9031 - val_loss: 1.0578 - val_accuracy: 0.7179
# Epoch 85/100
# 170/170 [==============================] - 224s 1s/step - loss: 0.2721 - accuracy: 0.9013 - val_loss: 1.0660 - val_accuracy: 0.7282
# Epoch 86/100
# 170/170 [==============================] - 272s 2s/step - loss: 0.2482 - accuracy: 0.9118 - val_loss: 1.1469 - val_accuracy: 0.7267
# Epoch 87/100
# 170/170 [==============================] - 229s 1s/step - loss: 0.2521 - accuracy: 0.9131 - val_loss: 1.2785 - val_accuracy: 0.6935
# Epoch 88/100
# 170/170 [==============================] - 267s 2s/step - loss: 0.2600 - accuracy: 0.9057 - val_loss: 1.2155 - val_accuracy: 0.6876
# Epoch 89/100
# 170/170 [==============================] - 307s 2s/step - loss: 0.2429 - accuracy: 0.9099 - val_loss: 1.4039 - val_accuracy: 0.6750
# Epoch 90/100
# 170/170 [==============================] - 311s 2s/step - loss: 0.2687 - accuracy: 0.9059 - val_loss: 1.2828 - val_accuracy: 0.6905
# Epoch 91/100
# 170/170 [==============================] - 318s 2s/step - loss: 0.2291 - accuracy: 0.9199 - val_loss: 1.1473 - val_accuracy: 0.7112
# Epoch 92/100
# 170/170 [==============================] - 309s 2s/step - loss: 0.2301 - accuracy: 0.9179 - val_loss: 1.1226 - val_accuracy: 0.7216
# Epoch 93/100
# 170/170 [==============================] - 312s 2s/step - loss: 0.2364 - accuracy: 0.9125 - val_loss: 1.1646 - val_accuracy: 0.7186
# Epoch 94/100
# 170/170 [==============================] - 315s 2s/step - loss: 0.2287 - accuracy: 0.9192 - val_loss: 1.1644 - val_accuracy: 0.7304
# INFO:tensorflow:Assets written to: E:/TesisMA/Modelos/256_CLAHE\Best_Modelo5_256_5_conv_dropout02-01_n1024_512_lr0005_dsCLAHE\assets
# Epoch 95/100
# 170/170 [==============================] - 311s 2s/step - loss: 0.2359 - accuracy: 0.9240 - val_loss: 1.3001 - val_accuracy: 0.7120
# Epoch 96/100
# 170/170 [==============================] - 311s 2s/step - loss: 0.2274 - accuracy: 0.9219 - val_loss: 1.1571 - val_accuracy: 0.7149
# Epoch 97/100
# 170/170 [==============================] - 319s 2s/step - loss: 0.2179 - accuracy: 0.9194 - val_loss: 1.3316 - val_accuracy: 0.6942
# Epoch 98/100
# 170/170 [==============================] - 311s 2s/step - loss: 0.2277 - accuracy: 0.9205 - val_loss: 1.2448 - val_accuracy: 0.7024
# Epoch 99/100
# 170/170 [==============================] - 310s 2s/step - loss: 0.2098 - accuracy: 0.9260 - val_loss: 1.2473 - val_accuracy: 0.7112
# Epoch 100/100
# 170/170 [==============================] - 317s 2s/step - loss: 0.2174 - accuracy: 0.9242 - val_loss: 1.3200 - val_accuracy: 0.7157

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

sn.set_palette(sn.color_palette("husl", 2))

plt.figure(figsize=(16, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy',color='red')
plt.plot(epochs_range, val_acc, label='Validation Accuracy', color='blue')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss',color='red')
plt.plot(epochs_range, val_loss, label='Validation Loss',color='blue')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# #### Confusion matrix

# %%
# Cargar mejor modelo 
model = tf.keras.models.load_model(checkpoint_filepath)

predictions = np.array([])
labels = np.array([])
for x, y in val_ds:
  predictions = np.concatenate([predictions, np.argmax(model.predict(x), axis=-1)])  
  labels= np.concatenate([labels, y])

matriz = tf.math.confusion_matrix(labels=labels, predictions=predictions).numpy()
df_cm = pd.DataFrame(matriz, index = class_names, columns = class_names)
plt.figure(figsize = (10,7))
sn.heatmap(df_cm, annot=True, cmap="YlGnBu",  fmt='g');

# %%
metricasCM(matriz)
# Out:
# De todas las X clasificadas solo el %  fue correcto [0.81, 0.82, 0.51, 0.67, 0.6]
# De todas las que deberían ser clasificadas como X el % fue corrcto  [0.79, 0.81, 0.53, 0.79, 0.47]

# %%
report = model.evaluate(val_ds,return_dict=True)
index=["Values"]
table=pd.DataFrame(report,index=index) 
table
# Out:
# 43/43 [==============================] - 17s 399ms/step - loss: 1.1644 - accuracy: 0.7304
#             loss  accuracy
# Values  1.164364  0.730428

# %%
def metricasCM(matriz):
    # Bien clasificados sobre columna / De todas las X clasificadas solo el %  fue correcto
    metrica1= []
    # Bien clasificados sobre la fila / De todas las que deberías ser clasificadas como X solo el % fue corrcto 
    metrica2= []
    for j in range(0,5):
        suma=0
        for i in range(0,5):
            suma=suma+matriz[i][j]
        metrica1.append((matriz[j][j]/suma).round(2))
        metrica2.append((matriz[j][j]/sum(matriz[j])).round(2))
    print("De todas las X clasificadas solo el %  fue correcto",metrica1)
    print("De todas las que deberían ser clasificadas como X el % fue corrcto ",metrica2)
metricasCM(matriz)
# Out:
# De todas las X clasificadas solo el %  fue correcto [0.79, 0.77, 0.54, 0.68, 0.63]
# De todas las que deberían ser clasificadas como X el % fue corrcto  [0.77, 0.83, 0.6, 0.74, 0.38]

# %% [markdown]
# #### TensorBoard

# %%
root_dir = "E:/TesisMA/Modelos/my_log"
def get_run_dir():
    import time
    run_id=time.strftime("run_%Y_%m_%d-%H_%M_%D")
    return os.path.join(root_dir,run_id)

tensorboard_cb = keras.callbacks.TensorBoard(get_run_dir())

# %%
# %load_ext tensorboard
# %tensorboard --logdir=E:/TesisMA/Modelos/my_log --port 6006
